# %% [markdown]
# <a href="https://colab.research.google.com/github/msy-bilecik/ist204_2024/blob/main/ist204_2024_12h_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Matplotlib
# grafik oluşturma kütüphanesi.

# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S=np.cos(X),np.sin(X)
plt.plot(X,C)
plt.plot(X,S)
plt.show()

# %%
x = [1,2,3,4]
y = [10,20,25,30]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color='lightblue', linewidth=3)
ax.scatter([2,4,6], [5,15,25], color='blue', marker='*')
ax.set_xlim(1, 6.5)
ax.set(title='An Example Axes',ylabel='Y-Axis',xlabel='X-Axis')
ax.legend(loc='upper left')
plt.savefig('foo.png')
# plt.title("graphic 1",fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = 2 * np.random.random((10, 10))
data2 = 3 * np.random.random((10, 10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2

# %% [markdown]
# kütüphane içinden örnek veri ekleme

# %%
from matplotlib.cbook import get_sample_data
img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))
fig, ax = plt.subplots()
im = ax.imshow(img, cmap='viridis',
               interpolation='nearest',
               vmin=-2, vmax=2)
# Out:
# <ipython-input-4-7c6ca5cea0ed>:2: MatplotlibDeprecationWarning: In a future release, get_sample_data will automatically load numpy arrays.  Set np_load to True to get the array and suppress this warning.  Set asfileobj to False to get the path to the data file and suppress this warning.
#   img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
fig3, axes = plt.subplots(nrows=2,ncols=2)
fig4, axes2 = plt.subplots(ncols=3)

fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

lines = ax.plot(x,y)

# %%
ax.scatter(x,y)
axes[0,0].bar([1,2,3],[3,4,5])
axes[1,0].barh([0.5,1,2.5],[0,1,2])
axes[1,1].axhline(0.45)
axes[0,1].axvline(0.65)
ax.fill(x,y,color='blue')
ax.fill_between(x,y,color='yellow')

# %%
ax1.hist(y)
# Out:
# (array([26.,  8.,  7.,  6.,  6.,  6.,  6.,  7.,  8., 20.]),
#  array([-9.99947166e-01, -7.99952450e-01, -5.99957733e-01, -3.99963016e-01,
#         -1.99968300e-01,  2.64169119e-05,  2.00021134e-01,  4.00015850e-01,
#          6.00010567e-01,  8.00005283e-01,  1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
ax3.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c2d582f5480>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c2d582f5a80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c2d582f6590>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c2d582f5570>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c2d582f51e0>],
#  'means': []}

# %%
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7c2d582f7130>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7c2d582f7b50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7c2d582f7910>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7c2d582f7610>}

# %%
axes2[0].pcolor(data2)
