# %% [markdown]
# <a href="https://colab.research.google.com/github/msy-bilecik/ist204_2024/blob/main/ist204_2024_12h_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Matplotlib
# grafik oluşturma kütüphanesi.

# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
X=np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S=np.cos(X),np.sin(X)
plt.plot(X,C)
plt.plot(X,S)
plt.show()

# %%
data = 2 * np.random.random((10, 10))
data2 = 3 * np.random.random((10, 10))
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2

# %% [markdown]
# kütüphane içinden örnek veri ekleme

# %%
from matplotlib.cbook import get_sample_data
img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))
# Out:
# <ipython-input-14-2bf0a3ca289a>:2: MatplotlibDeprecationWarning: In a future release, get_sample_data will automatically load numpy arrays.  Set np_load to True to get the array and suppress this warning.  Set asfileobj to False to get the path to the data file and suppress this warning.
#   img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %%
fig = plt.figure()
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
fig3, axes = plt.subplots(nrows=2,ncols=2)
fig4, axes2 = plt.subplots(ncols=3)

fig2 = plt.figure(figsize=plt.figaspect(2.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5749fd9817cf> in <cell line: 2>()
#       1 fig = plt.figure()
# ----> 2 fig.add_axes()
#       3 ax1 = fig.add_subplot(221)
#       4 ax3 = fig.add_subplot(212)
#       5 fig3, axes = plt.subplots(nrows=2,ncols=2)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in add_axes(self, *args, **kwargs)
#     603
#     604         if not len(args) and 'rect' not in kwargs:
# --> 605             raise TypeError(
#     606                 "add_axes() missing 1 required positional argument: 'rect'")
#     607         elif 'rect' in kwargs:
#
# TypeError: add_axes() missing 1 required positional argument: 'rect'

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

lines = ax.plot(x,y)

# %%
ax.scatter(x,y)
axes[0,0].bar([1,2,3],[3,4,5])
axes[1,0].barh([0.5,1,2.5],[0,1,2])
axes[1,1].axhline(0.45)
axes[0,1].axvline(0.65)
ax.fill(x,y,color='blue')
ax.fill_between(x,y,color='yellow')

# %%
fig, ax = plt.subplots()
im = ax.imshow(img, cmap='Greys',
               interpolation='nearest',
               vmin=-2, vmax=2)
