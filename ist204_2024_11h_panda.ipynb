# %% [markdown]
# <a href="https://colab.research.google.com/github/msy-bilecik/ist204_2024/blob/main/ist204_2024_11h_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Panda
#
# python üzerinde excel gibi çalışma imkanı sağlayan bir kütüphanedir.
# *

# %%
import pandas as pd

# %%
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = [1, 2, 3])

# %%
display(df)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

display(df)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
{"variable" : [4 ,5, 6],
"value" : [210, 120,250],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples(
[('d',1),('d',2),('e',2)],
names=['n','v']))

display(df)
# Out:
#      variable  value   c
# n v
# d 1         4    210  10
#   2         5    120  11
# e 2         6    250  12

# %%
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [1, 2, 3])
display(df)
df = pd.melt(df)

display(df)
# Out:
#    a    b   c
# 1  4  210  10
# 2  5  120  11
# 3  6  250  12
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b    210
# 4        b    120
# 5        b    250
# 6        c     10
# 7        c     11
# 8        c     12

# %%
df1 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [1, 2, 3])

display(df1)
df2 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [10, 11, 12])

display(df2)

df3=pd.concat([df1,df2])
display(df3)
df3=df3.reset_index()
display(df3)
# Out:
#    a    b   c
# 1  4  210  10
# 2  5  120  11
# 3  6  250  12
#     a    b   c
# 10  4  210  10
# 11  5  120  11
# 12  6  250  12
#     a    b   c
# 1   4  210  10
# 2   5  120  11
# 3   6  250  12
# 10  4  210  10
# 11  5  120  11
# 12  6  250  12
#    index  a    b   c
# 0      1  4  210  10
# 1      2  5  120  11
# 2      3  6  250  12
# 3     10  4  210  10
# 4     11  5  120  11
# 5     12  6  250  12

# %%
df1 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [1, 2, 3])

display(df1)
df2 = pd.DataFrame(
{"d" : [4 ,5, 6],
"e" : [210, 120,250],
"f" : [10, 11, 12]},
index = [10, 11, 12])

display(df2)

df3=pd.concat([df1,df2])
display(df3)
# Out:
#    a    b   c
# 1  4  210  10
# 2  5  120  11
# 3  6  250  12
#     d    e   f
# 10  4  210  10
# 11  5  120  11
# 12  6  250  12
#       a      b     c    d      e     f
# 1   4.0  210.0  10.0  NaN    NaN   NaN
# 2   5.0  120.0  11.0  NaN    NaN   NaN
# 3   6.0  250.0  12.0  NaN    NaN   NaN
# 10  NaN    NaN   NaN  4.0  210.0  10.0
# 11  NaN    NaN   NaN  5.0  120.0  11.0
# 12  NaN    NaN   NaN  6.0  250.0  12.0

# %%
df1 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [1, 2, 3])

display(df1)
df2 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [10, 11, 12])

display(df2)

df3=pd.concat([df1,df2],axis=1)
display(df3)
# Out:
#    a    b   c
# 1  4  210  10
# 2  5  120  11
# 3  6  250  12
#     a    b   c
# 10  4  210  10
# 11  5  120  11
# 12  6  250  12
#       a      b     c    a      b     c
# 1   4.0  210.0  10.0  NaN    NaN   NaN
# 2   5.0  120.0  11.0  NaN    NaN   NaN
# 3   6.0  250.0  12.0  NaN    NaN   NaN
# 10  NaN    NaN   NaN  4.0  210.0  10.0
# 11  NaN    NaN   NaN  5.0  120.0  11.0
# 12  NaN    NaN   NaN  6.0  250.0  12.0

# %%
df1 = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [210, 120,250],
"c" : [10, 11, 12]},
index = [1, 2, 3])

df1=df1.drop(columns=['b'])
display(df1)
# Out:
#    a   c
# 1  4  10
# 2  5  11
# 3  6  12

# %% [markdown]
# ##CSV okuma

# %%
url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/homes.csv'
df1 = pd.read_csv(url)

# %%
display(df1)
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0    142      160         28        10        5         3      60      0.28
# 1    175      180         18         8        4         1      12      0.43
# 2    129      132         13         6        3         1      41      0.33
# 3    138      140         17         7        3         1      22      0.46
# 4    232      240         25         8        4         3       5      2.05
# 5    135      140         18         7        4         3       9      0.57
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 9     89       90         10         5        3         1      43      0.30
# 10   153      157         22         8        3         3      18      0.38
# ...

# %%
display(df1.head(7))
display(df1.tail(7))
# Out:
#    Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142      160         28        10        5         3      60      0.28
# 1   175      180         18         8        4         1      12      0.43
# 2   129      132         13         6        3         1      41      0.33
# 3   138      140         17         7        3         1      22      0.46
# 4   232      240         25         8        4         3       5      2.05
# 5   135      140         18         7        4         3       9      0.57
# 6   150      160         20         8        4         3      18      4.00
#
#     "Taxes"
# 0      3167
# 1      4033
# 2      1471
# 3      3204
# 4      3613
# 5      3028
# 6      3131
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 43   212      230         39        12        5         3     202      4.29
# 44   145      145         18         8        4         2      44      0.22
# ...

# %%
display(df1)
df2=df1.iloc[10:20]
display(df2)
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0    142      160         28        10        5         3      60      0.28
# 1    175      180         18         8        4         1      12      0.43
# 2    129      132         13         6        3         1      41      0.33
# 3    138      140         17         7        3         1      22      0.46
# 4    232      240         25         8        4         3       5      2.05
# 5    135      140         18         7        4         3       9      0.57
# 6    150      160         20         8        4         3      18      4.00
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 9     89       90         10         5        3         1      43      0.30
# 10   153      157         22         8        3         3      18      0.38
# ...

# %%
df1.loc[df1.Sell>200]
# Out:
#     Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 4    232      240         25         8        4         3       5      2.05
# 7    207      225         22         8        4         2      16      2.22
# 8    271      285         30        10        5         2      30      0.53
# 12   234      238         25         8        4         2       2      1.61
# 21   293      305         26         8        4         3       6      0.46
# 28   567      625         64        11        4         4       4      0.85
# 38   265      270         36        10        6         3      33      1.20
# 43   212      230         39        12        5         3     202      4.29
# 47   247      252         29         9        4         2       4      1.25
#
#      "Taxes"
# 4       3613
# 7       5158
# 8       5702
# 12      2087
# 21      7088
# 28     12192
# 38      5853
# 43      3648
# 47      4626

# %%
df1["Sell"].quantile([0.25,0.75])
# Out:
# 0.25    135.00
# 0.75    182.25
# Name: Sell, dtype: float64

# %%
def kdvHesapla(deger):
    return deger+deger*0.2

kdvHesapla(100)

df1.Sell.apply(kdvHesapla)
# Out:
# 0     170.4
# 1     210.0
# 2     154.8
# 3     165.6
# 4     278.4
# 5     162.0
# 6     180.0
# 7     248.4
# 8     325.2
# 9     106.8
# 10    183.6
# 11    104.4
# 12    280.8
# 13    127.2
# 14    210.0
# 15    198.0
# 16    199.2
# 17    163.2
# 18    177.6
# 19    181.2
# 20    216.0
# 21    351.6
# 22    200.4
# 23    228.0
# 24    220.8
# 25    188.4
# 26    132.0
# 27    162.0
# 28    680.4
# 29    216.0
# 30    219.6
# 31    222.0
# 32    182.4
# 33    177.6
# 34    182.4
# 35    175.2
# 36    204.0
# 37    152.4
# 38    318.0
# 39    188.4
# 40    153.6
# 41    132.0
# 42    147.6
# 43    254.4
# 44    174.0
# 45    154.8
# 46    171.6
# 47    296.4
# 48    133.2
# 49    159.6
# Name: Sell, dtype: float64

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.scatter(x=df1.columns[6],y=df1.columns[7])
# Out:
# <Axes: xlabel=' "Age"', ylabel=' "Acres"'>

# %%
df1.Sell=df1.Sell*1000
df1["KDV"]=df1.Sell.apply(kdvHesapla)

# %%
df1
# Out:
#       Sell   "List"   "Living"   "Rooms"   "Beds"   "Baths"   "Age"   "Acres"  \
# 0   142000      160         28        10        5         3      60      0.28
# 1   175000      180         18         8        4         1      12      0.43
# 2   129000      132         13         6        3         1      41      0.33
# 3   138000      140         17         7        3         1      22      0.46
# 4   232000      240         25         8        4         3       5      2.05
# 5   135000      140         18         7        4         3       9      0.57
# 6   150000      160         20         8        4         3      18      4.00
# 7   207000      225         22         8        4         2      16      2.22
# 8   271000      285         30        10        5         2      30      0.53
# 9    89000       90         10         5        3         1      43      0.30
# 10  153000      157         22         8        3         3      18      0.38
# ...
